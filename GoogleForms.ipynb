# %%
import pandas as pd
import numpy as np
from math import ceil
import time
import glob,os
import re

# %%
users[users['Username']=='users']
# Out:
#                    Timestamp                    Username  \
# 0  2018/04/30 2:57:22 PM EST       mpardassie@ryerson.ca
# 1  2018/05/07 9:39:35 AM EST          fsamouh@ryerson.ca
# 2  2018/05/07 5:12:47 PM EST       ahooshmand@ryerson.ca
# 3  2018/05/07 5:19:09 PM EST  nasim.mirahmadi@ryerson.ca
# 4  2018/05/07 6:18:23 PM EST    mehdi.meshkani@gmail.com
#
#   Please enter your name and press continue.  \
# 0                          Michael Pardassie
# 1                               Farah Samouh
# 2                           Hamed Hooshmand
# 3                           Nasim Mirahmadi
# 4                             Mehdi Meshkani
#
#   Please enter your name and press continue..1      Age  Gender  \
# 0                                          NaN  18 - 24    Male
# 1                                          NaN  18 - 24  Female
# 2                                          NaN  25 - 29    Male
# 3                                          NaN  30 - 39  Female
# ...
